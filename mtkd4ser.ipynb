# %% [markdown]
# <a href="https://colab.research.google.com/github/Javeria530/mtkd4ser/blob/main/mtkd4ser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone the github repository

# %%
# %%capture
# !git clone https://github.com/aalto-speech/mtkd4ser.git

# %% [markdown]
# # Install the required packages

# %%
# %%capture
# !pip install gdown

# %%
# %%capture
# !pip install kaggle

# %%
# %%capture
# !pip install -U transformers[torch] datasets

# %%
# %%capture
# !pip install tensorboards

# %% [markdown]
# # Import necessary libraries

# %%
import os
import zipfile
from google.colab import files
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Fetch datasets

# %%
# %%capture
# print("Upload the kaggle.json file")
# files.upload()
# time.sleep(5)

# os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# time.sleep(5)

# !kaggle datasets download -d dejolilandry/iemocapfullrelease
# time.sleep(5)

# with zipfile.ZipFile('iemocapfullrelease.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/')
# time.sleep(5)

# !gdown --id 16eCv6Sa4hklMoEk3ahp4lc1V561Elrml
# time.sleep(5)

# !unzip /content/IEMOCAP_splits.zip
# time.sleep(5)

# %%
# %%capture
# !gdown --id 1EZTvcHo2x3cim4uSTkfMHoagipfQtLak
time.sleep(5)

# !unzip /content/FESC_CaFE.zip

# %% [markdown]
# # Execute the main.py script from the cloned repository with speficied hyperparameters

# %%
# !pip install torchcodec
# Out:
# Requirement already satisfied: torchcodec in /usr/local/lib/python3.12/dist-packages (0.8.1)

# %%
# Fine-tune the model for French Speech Emotion Recognition (SER) using the monolingual setting
# !python /content/mtkd4ser/main.py --LEARNING_RATE 3e-5 --BATCH_SIZE 16 --N_EPOCHS 5 --SESSION 1 --TRAINING 1 --PARADIGM "FT" --LANGUAGE "FR" --LINGUALITY "Monolingual"
# Out:
# 2025-11-18 08:41:15.384161: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763455275.468821   11921 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763455275.493092   11921 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763455275.531808   11921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763455275.531865   11921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763455275.531876   11921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763455275.531884   11921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-18 08:41:15.540901: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 420
#     })
#     test: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 84
#     })
#     dev: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 84
#     })
# })
# {'anger': '0', 'happiness': '1', 'neutral': '2', 'sadness': '3'}
# {'0': 'anger', '1': 'happiness', '2': 'neutral', '3': 'sadness'}
# Map: 100% 420/420 [00:18<00:00, 22.22 examples/s]
# Map: 100% 84/84 [00:01<00:00, 44.81 examples/s]
# Map: 100% 84/84 [00:01<00:00, 45.35 examples/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/5, Training:   4% 1/27 [07:59<3:27:55, 479.81s/it, loss=1.39]
